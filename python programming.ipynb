# %% [markdown]
# # Lists

# %% [markdown]
# # 1.find the largest element in the given list

# %%
def largest_val(l):
    l=list(set(l))
    l.sort()
    return l[-1]
l=eval(input("enter a list"))
print(largest_val(l))

# %% [markdown]
# # 2.remove the duplicate element from the list

# %%
def rem_duplicate(l):
    out=[]
    for i in l:
        if i not in out:
            out.append(i)
    return out
l=eval(input("enter a list"))
print(rem_duplicate(l))

# %% [markdown]
# # 3.wap to print the second largest element in the given list

# %%
def sec_largest(l):
    l=list(set(l)) #sets removes duplicate values here
    l.sort()
    return l[-2]
l=eval(input("Enter a list: "))
print(sec_largest(l))

# %% [markdown]
# # 4.wap merge two list without using + operator

# %%
def merge_list(l1,l2):
    out=l1
    for i in l2:
        out.append(i)
    return out
l1=eval(input("enter first list1"))
l2=eval(input("enter second list2"))
print(merge_list(l1,l2))

# %% [markdown]
# # 5.wap to find the sum of interger present in a given a list

# %%
def sum_int(l):
    sum=0
    for i in l:
        if type(i)==int:
            sum=sum+i
    return sum
l=eval(input("enter the list"))
print(sum_int(l))
# enter the list[1,"hello",2,"world",3]
# 6
# Out:
# 10

# %% [markdown]
# # 6.wap to reverse the list using two pointer

# %%
def rev_list(l):
    i=0
    j=len(l)-1
    while i<j:
        l[i],l[j]=l[j],l[i]
        i=i+1
        j=j-1
    return l
l=eval(input("enter a list"))
print(rev_list(l))
# Out:
# [3, 2, 1]

# %% [markdown]
# # 7.wap to check wether the list is palidrome or not using two pointer

# %%
def palindrome(l):
    i=0
    j=len(l)-1
    flag=True
    while i<j:
        if l[i]!=l[j]:
            flag=False
            break
        i=i+1
        j=j-1
    if flag:
        return 'Palindrome'
    else:
        return 'Not Palindrome'
l=eval(input("Enter a list: "))
print(palindrome(l))

# %% [markdown]
# # 8.wap to find commom elements from the two lists

# %%
def common_val(l1,l2):
    out=[]
    for i in l1:
        if i in l2 and i not in out:
            out.append(i)
    return out
l1=eval(input("enter first list"))
l2=eval(input("enter second list"))
print(common_val(l1,l2))

# %% [markdown]
# # 9.wap to find frequesncy of elements from the given list

# %%
def freq_element(l):
    out=[]
    for i in l:
        if i not in out:
            print(i,':',l.count(i))
            out.append(i)
l=eval(input("enter the element:"))
freq_element(l)
# Out:
# 1 : 1
# 2 : 2
# 3 : 3

# %% [markdown]
# # 10.wap to rotate the list for n number of times to right or left

# %%
def right_rotate(l,n):
    n=n%len(l)
    out=l[-n:]+l[:-n]
    return out
l=eval(input("enter a list"))
n=int(input("enter a number"))
print(right_rotate(l,n))

# %%
# left rotation
def left_rotate(l,n):
    n=n%len(l)
    out=l[n:]+l[:n]
    return out
l=eval(input("enter a list"))
n=int(input("enter a number"))
print(left_rotate(l,n))

# %% [markdown]
# # 11.wap to move zeros to end of the list

# %%
def move_zero(l):
    zero=[]
    out=[]
    for i in l:
        if i!=0:
            out.append(i)
        else:
            zero.append(i)
    return out+zero
l=eval(input("Enter a list: "))
print(move_zero(l))

# %% [markdown]
# # 12.wap to find missing number from list(1 to n)

# %%
 #applicable only when single value is missing
def missing_num(l):
    n=int(input("enter n value"))
    sum_val=sum(l)
    res=n*(n+1)//2
    return res-sum_val
l=eval(input("enter list"))
print(missing_num(l))
# Out:
# 4

# %%
# applicable for multiple values missing
def missing_num(l):
    n=int(input("enter n value"))
    sum_val=sum(l)
    res=n*(n+1)//2
    return res-sum_val
l=eval(input("enter list"))
n=int(input("enter val"))
for i in range(1,n+1):
    if i not in l:
        print(i)
# Out:
# 3
# 4

# %% [markdown]
# # 13.wap to find the pair with given sum

# %%
def sam(l, n):
    out = []
    for i in range(len(l)):
        if l[i] == n:
            out.append([l[i]])
        else:
            for j in range(i + 1, len(l)):
                if l[i] + l[j] == n:
                    out.append([l[i], l[j]])
    return out

l = eval(input("Enter the list: "))
n = int(input("Enter n value: "))
print(sam(l, n))

# %% [markdown]
# # Assignment Questions

# %% [markdown]
# # 1.WAP to Find First Repeating Element

# %%
def first_repeat(l):
    seen = []
    for i in l:
        if i in seen:
            return i
        seen.append(i)
    return "No repeating element"

l = eval(input("Enter a list: "))
print(first_repeat(l))
# Enter a list: 1,2,3,4,2,5,1
# 2
# Out:
# 2

# %% [markdown]
# # 2.WAP to Find Index of Given Element Without Using index()

# %%
def find_index(l, target):
    for i in range(len(l)):
        if l[i] == target:
            return i
    return "Element not found"

l = eval(input("Enter a list: "))
target = eval(input("Enter element to find: "))
print(find_index(l, target))
# Enter a list: 10,20,30,40,50
# Enter element to find: 30
# 2
# Out:
# 2

# %% [markdown]
# # 3.WAP to Count Occurrence of Given Element

# %%
def count_occur(l, target):
    count = 0
    for i in l:
        if i == target:
            count += 1
    return count

l = eval(input("Enter a list: "))
target = eval(input("Enter element to find: "))
print(count_occur(l, target))
# Enter a list: 1,2,3,2,4,2,5
# Enter element to find: 2
# 3
# Out:
# 2

# %% [markdown]
# # 4.WAP to Extract Extensions from List

# %%
def get_extension(l):
    out = []
    for i in l:
        ext = i.split(".")[1]
        out.append(ext)
    return out

l = eval(input("Enter a list: "))
print(get_extension(l))
# Enter a list: ['python.py','prol.html','data.db','google.com']
# ['py', 'html', 'db', 'com']
# Out:
# ['py', 'html', 'db', 'com']

# %% [markdown]
# # 5.wap to extract all the integer which are multiple of 5 and has three digit in it from list

# %%
def extract(l):
    out = []
    for i in l:
        if type(i) == int and i % 5 == 0 and len(str(i)) == 3:
            out.append(i)
    return out

l = eval(input("Enter a list: "))
print(extract(l))
#Enter a list: [100,200,15,300,25,150,1000,50]
# [100, 200, 300, 150]
# Out:
# [100, 200, 300, 150]

# %% [markdown]
# # 6.WAP to Split List into Even and Odd List

# %%
def split_list(l):
    even = []
    odd = []
    for i in l:
        if i % 2 == 0:
            even.append(i)
        else:
            odd.append(i)
    return even, odd

l = eval(input("Enter a list: "))
even, odd = split_list(l)
print("Even:", even)
print("Odd:", odd)
# Even: [2, 4, 6, 8]
# Odd: [1, 3, 5, 7]
# Out:
# Even: [2, 4, 6, 8]
# Odd: [1, 3, 5, 7]

# %% [markdown]
# # 7.WAP to Find Duplicate Elements from List

# %%
def find_duplicates(l):
    seen = []
    duplicates = []
    for i in l:
        if i in seen:
            if i not in duplicates:
                duplicates.append(i)
        else:
            seen.append(i)
    return duplicates

l = eval(input("Enter a list: "))
print(find_duplicates(l))
# Out:
# [2, 1, 3]

# %% [markdown]
# # 8.WAP to Check Whether List is Sorted or Not

# %%
def is_sorted(l):
    for i in range(len(l) - 1):
        if l[i] > l[i+1]:
            return "Not Sorted"
    return "Sorted"

l = eval(input("Enter a list: "))
print(is_sorted(l))
# Enter a list: 1,2,3,4,5
# Sorted
# Enter a list: 1,3,2,4,5
# Not Sorted
# Out:
# Not Sorted

# %% [markdown]
# # 9.wap to find first non repeated element in the list

# %%
def first_non_repeat(l):
    for i in l:
        if l.count(i) == 1:
            return i
    return "No non repeating element"

l = eval(input("Enter a list: "))
print(first_non_repeat(l))
# Enter a list: 1,2,3,2,4,1,5
# 3

# %% [markdown]
# # 10.WAP to Find Element Repeated Most Number of Times

# %%
def most_repeated(l):
    seen = {}
    for i in l:
        seen[i] = seen.get(i, 0) + 1
    max_val = 0
    result = None
    for key, val in seen.items():
        if val > max_val:
            max_val = val
            result = key
    return result

l = eval(input("Enter a list: "))
print(most_repeated(l))
# Enter a list: 1,2,3,2,4,2,1,3,3,3
# 3
# Out:
# 3

# %% [markdown]
# # string

# %% [markdown]
# # 1.reverse a string

# %%
def rev_str(s):
    l=list(s)
    i=0
    j=len(l)-1
    while i<j:
        l[i],l[j]=l[j],l[i]
        i=i+1
        j=j-1
    return "".join(l)
s=input("enter a string")
print(rev_str(s))
# Out:
# olleh

# %% [markdown]
# # 2.wap to check palindrome whtether the string is palindrome or not using two pointers

# %%
def palindrome(s):
    i = 0
    j = len(s) - 1
    flag = True

    while i < j:
        if s[i] != s[j]:
            flag = False
            break
        i = i + 1
        j = j - 1

    if flag:
        return "Palindrome"
    else:
        return "Not Palindrome"


s = input("Enter a string: ")
print(palindrome(s))
# Out:
# Palindrome

# %% [markdown]
# # 3.count of vowels nd consonents in given string

# %%
def count_vow_con(s):
    vow=0
    cons=0
    for i in s:
        if i in "AEIOUaeiou":
            vow = vow+1
        elif 'A' <= i <= 'Z'or 'a' <= i <= 'z':
            cons = cons+1
    return vow,cons
s=input("Enter a string: ")
print(count_vow_con(s))
# Out:
# (2, 1)

# %% [markdown]
# # 4.wap to count occurrence of element in given string

# %%
def occur_element(s):
    count=0
    element=input("enter element: ")
    for i in s:
        if i==element:
            count = count+1
    return count
s=input("Enter a string: ")
print(occur_element(s))
# Out:
# 2

# %% [markdown]
# # 5.to print occrence if substring from given string

# %%
def occur_substr(s,sub):
    count=0
    for i in range(len(s)-len(sub)+1):
        if s[i:i+len(sub)]==sub:
            count = count+1
    return count
S=input("Enter a string: ")
sub=input("Enter a substring: ")
print(occur_substr(S,sub))
# Out:
# 2

# %% [markdown]
# # 6.remove spaces from a given string

# %%
def rem_spac(s):
    res=""
    for i in s:
        if i!=" ":
            res=res+i
    return res
s=input("Enter a string: ")
print(rem_spac(s))
# Out:
# hai

# %% [markdown]
# # online-7.wap to find the duplicate character from the given string

# %%
def duplicate_char(s):
    dup=""
    res=""
    for i in s:
        if i in res:
            dup = dup + i
        else:
            res = res + i
    return dup
s=input("enter a string")
print(duplicate_char(s))
# Out:
# l

# %% [markdown]
# # 8.wap to find the largest the word from the given strig

# %%
def largest_word(s):
    words = s.split()
    large = ""

    for i in words:
        if len(i) > len(large):
            large = i

    return large


s = input("Enter a string: ")
print("Largest word:", largest_word(s))
# Out:
# Largest word: programming

# %% [markdown]
# # 9.wap to check whether given string are anagram or not

# %%
def anagram(s1,s2):
    if sorted(s1) == sorted(s2):
        return "anagram"
    else:
        return "not anagram"
s1=input("enter first string: ").replace(" ","").lower()
s2=input("enter second string: ").replace(" ","").lower()
print(anagram(s1,s2))
# Enter first string: listen
# Enter second string: silent
# Anagram
# Out:
# anagram

# %% [markdown]
# # 10.wap to check whether string is panagram or not

# %%
def panagram(s):
    import string
    str_set=set(s)
    alpha=set(string.ascii_lowercase)
    if alpha.issubset(str_set):
        return "anagram"
    else:
        return "not anagram"
s=input("enter string:").lower()
print(panagram(s))
# enter string:the quick brown fox jumps over the lazy dog
# anagram
# Out:
# anagram

# %% [markdown]
# # 11.wap to print first non repeating character from string

# %%
def non_repeat(s):
    for i in range(len(s)):
        c=0
        for j in range(len(s)):
            if s[i] == s[j]:
                c=c+1
        if c==1:
            return s[i]
s=input("enter string:")
print(non_repeat(s))
#enter string:swiss
# w
# Out:
# w

# %% [markdown]
# # 12.wap to check the rotation of the string

# %%
def rotation_str(s1,s2):
    if len(s1) == len(s2) and s2 in (s1+s2):
        print("rotation of string")
    else:
        print("rotation failed")
s1=input("enter first string")
s2=input("enter second string")
rotation_str(s1,s2)
# Out:
# rotation of string

# %% [markdown]
# # 13.wap to insert the substring into the main string from the given index number

# %%
def add_substr(s,sub,ind):
    if ind<0 or ind>len(s):
        return "invalid index"
    else:
        new_str=s[:ind]+sub+s[ind:]
        return new_str
s=input("enter string")
sub=input("enter substring")
ind=int(input("enter index"))
print(add_substr(s,sub,ind))
# Out:
# stmring programming

# %% [markdown]
# # 14.wpa to print largest palindrome substring from the given string

# %%
def large_pali_sub(s):
    large=""
    for i in range(len(s)):
        for j in range(i+1,len(s)+1):
            sub=s[i:j]
            if sub == sub[::-1] and len(sub)>len(large):
                large=sub
    return large
s=input("enter string")
print(large_pali_sub(s))
# Out:
# aba

# %% [markdown]
# # string assignment questions

# %% [markdown]
# # 1.wap to convert lowercase character to uppercase without using upper()

# %%
def lower_to_upper(ch):
    if 'a' <= ch <= 'z':
        return chr(ord(ch) - 32)
    else:
        return "Not a lowercase character"

ch = input("Enter a lowercase character: ")
print(lower_to_upper(ch))
# Enter a lowercase character: d
# D
# Out:
# D

# %% [markdown]
# # 2.wap to find the frequesncy of each character from given string

# %%
def char_frequency(s):
    for i in s:
        c = 0
        for j in s:
            if i == j:
                c = c + 1
        print(i, "=", c)

s = input("Enter a string: ")
char_frequency(s)
# Out:
# h = 1
# e = 1
# l = 2
# l = 2
# o = 1

# %% [markdown]
# # 3.wap to remove duplicate characters from given string

# %%
def remove_duplicates(s):
    result = ""

    for ch in s:
        if ch not in result:
            result = result + ch

    return result

s = input("Enter a string: ")
print(remove_duplicates(s))
# Out:
# progamin

# %% [markdown]
# # 4.wap to reverse each word from given string

# %%
def reverse_each_word(s):
    words = s.split()
    result = ""

    for word in words:
        result = result + word[::-1] + " "

    return result

s = input("Enter a string: ")
print(reverse_each_word(s))
# Out:
# olleh

# %% [markdown]
# # 5.wap to reverse the order of string
# # inp="how are you"
# # out="you are how"

# %%
def reverse_order(s):
    words = s.split()
    result = " ".join(words[::-1])
    return result

s = input("Enter a string: ")
print(reverse_order(s))
# Out:
# you are how

# %% [markdown]
# # 6.wap to store each word into list from given string without using split()

# %%
def store_words(s):
    l = []
    word = ""

    for ch in s:
        if ch != " ":
            word = word + ch
        else:
            l.append(word)
            word = ""

    l.append(word)
    return l

s = input("Enter a string: ")
print(store_words(s))
# Enter a string: how are you
# ['how', 'are', 'you']
# Out:
# ['how', 'are', 'you']

# %% [markdown]
# # 7.wap to count uppercase,lowercase,digit,special symbol,spaces and word from given string

# %%
def count_characters(s):
    upper = lower = digit = special = space = word = 0

    for ch in s:
        if 'A' <= ch <= 'Z':
            upper += 1
        elif 'a' <= ch <= 'z':
            lower += 1
        elif '0' <= ch <= '9':
            digit += 1
        elif ch == ' ':
            space += 1
        else:
            special += 1

    word = len(s.split())

    print("Uppercase =", upper)
    print("Lowercase =", lower)
    print("Digits =", digit)
    print("Special Symbols =", special)
    print("Spaces =", space)
    print("Words =", word)

s = input("Enter a string: ")
count_characters(s)
# Enter a string: Hello World 123 @#
# Out:
# Uppercase = 2
# Lowercase = 8
# Digits = 3
# Special Symbols = 2
# Spaces = 3
# Words = 4

# %% [markdown]
# # 8.wap to print second word from given string

# %%
def second_word(s):
    words = s.split()

    if len(words) >= 2:
        return words[1]
    else:
        return "Second word not found"

s = input("Enter a string: ")
print(second_word(s))
# Enter a string: how are you
# Out:
# are

# %% [markdown]
# # 9.wap to get following output
# # inp='python is fun'
# # out={'python':6,'is':2,'fun':3}

# %%
def word_length_dict(s):
    d = {}

    words = s.split()

    for word in words:
        d[word] = len(word)

    return d

s = input("Enter a string: ")
print(word_length_dict(s))
# Enter a string: python is fun
# Out:
# {'python': 6, 'is': 2, 'fun': 3}

# %% [markdown]
# # NUMBERS

# %% [markdown]
# # 1.wap to check whether the given number is prime number or not

# %%
def prime_num(n):
    count=0
    for i in range(1,n+1):
        if n % i == 0:
            count = count + 1
    if count == 2:
        return "prime number"
    else:
        return "not prime"
n=int(input("enter the number"))
print(prime_num(n))
# Out:
# not prime

# %% [markdown]
# # 2.wap to reverse the number

# %%
def rev_num(n):
    rev=0
    while n>0:
        ld=n%10
        rev=rev*10+ld
        n=n//10
    return rev
n=int(input("enter the number"))
print(rev_num(n))
# o/p:
# enter the number45
# 54
# Out:
# 321

# %% [markdown]
# # 3.wap to check whether given number is palindrome or not

# %%
def palindrome(n):
    rev=0
    temp=n
    while temp>0:
        ld=temp%10
        rev=rev*10+ld
        temp=temp//10
    if n ==rev:
        return "palindrome"
    else:
        return "not palindrome"
n=int(input("enter the number"))
print(palindrome(n))
# o/p:
# enter the number12
# not palindrome
# Out:
# not palindrome

# %% [markdown]
# # 4.wap to check whether the given number is armstrong or not

# %%
def armstrong_num(n):
    sum=0
    for i in str(n):
        num=int(i)
        sum=sum+num**len(str(n))
    if sum==n:
        return "armstrong number"
    else:
        return "not armstrong number"
n=int(input("enter the number"))
print(armstrong_num(n))
# o/p:
# enter the number153
# armstrong number
# Out:
# armstrong number

# %% [markdown]
# # 5.wap to check whether the given number is strong number or not

# %%
def strong_num(n):
    sum=0
    for i in str(n):
        num=int(i)
        fact=1
        for j in range(1,num+1):
            fact=fact*j
        sum=sum+fact
    if sum==n:
        return "strong number"
    else:
        return "not strong number"
n=int(input("enter the number"))
print(strong_num(n))
# o/p:
# enter the number145
# strong number
# Out:
# not strong number

# %% [markdown]
# # 6.wap to check whether given number is perfect number or not

# %%
def perfect_num(n):
    sum = 0
    for i in range(1, n):
        if n % i == 0:
            sum = sum + i

    if sum == n:
        return "perfect number"
    else:
        return "not perfect number"

n = int(input("enter val: "))
print(perfect_num(n))
# o/p:
# enter val: 6
# perfect number
# Out:
# perfect number

# %% [markdown]
# # assignment on NUMBERS

# %% [markdown]
# # 1.wap to find factorial of given number

# %%
def factorial(n):
    fact = 1
    for i in range(1, n+1):
        fact = fact * i
    if n < 0:
        return "Invalid number"
    return fact

n = int(input("Enter the number: "))
print(factorial(n))
# Enter the number: 5
# 120
# Out:
# 120

# %% [markdown]
# # 2.wap to find GCD/HCF of two numbers

# %%
def gcd(a, b):
    for i in range(1, min(a, b) + 1):
        if a % i == 0 and b % i == 0:
            result = i
    return result

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
print(gcd(a, b))
# Enter first number: 12
# Enter second number: 18
# 6
# Out:
# 6

# %% [markdown]
# # 3.wap to find LCM of two numbers

# %%
def lcm(a, b):
    result = max(a, b)
    while True:
        if result % a == 0 and result % b == 0:
            return result
        result = result + 1

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
print(lcm(a, b))
# Enter first number: 12
# Enter second number: 18
# 36
# Out:
# 36

# %% [markdown]
# # 4.wap to convert decimal to binary

# %%
def dec_to_bin(n):
    binary = ""
    while n > 0:
        rem = n % 2
        binary = str(rem) + binary
        n = n // 2
    return binary

n = int(input("Enter the number: "))
print(dec_to_bin(n))
# Enter the number: 10
# 1010
# Out:
# 1010

# %% [markdown]
# # 5.wap to convert binary to decimal

# %%
def bin_to_dec(n):
    decimal = 0
    power = 0
    while n > 0:
        rem = n % 10
        decimal = decimal + rem * (2 ** power)
        power = power + 1
        n = n // 10
    return decimal

n = int(input("Enter binary number: "))
print(bin_to_dec(n))
# Enter binary number: 1010
# 10
# Out:
# 10

# %% [markdown]
# # 6.wap to swap two numbers with using temporary variable

# %%
def swap(a, b):
    temp = a
    a = b
    b = temp
    return a, b

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
a, b = swap(a, b)
print("a =", a)
print("b =", b)
# Enter first number: 10
# Enter second number: 20
# a = 20
# b = 10
# Out:
# a = 20
# b = 10

# %% [markdown]
# # 7.wap to swap two numbers without using temporary variable

# %%
def swap(a, b):
    a = a + b
    b = a - b
    a = a - b
    return a, b
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
a, b = swap(a, b)
print("a =", a)
print("b =", b)
# Enter first number: 10
# Enter second number: 20
# a = 20
# b = 10
# Out:
# a = 20
# b = 10

# %% [markdown]
# # 1.wap to generate 10 fibonacci series

# %%
def fib(n):
    n1=0
    n2=1
    for i in range(1,n+1):
        print(n1,end="")
        n3=n1+n2
        n1,n2=n2,n3
n=int(input("enter val:"))
fib(n)
# Out:
# 0112358132134

# %% [markdown]
# # 2.wap to find the sum of individual digit

# %%
def sum_individual(n):
    sum=0
    while n>0:
        ld=n%10
        sum=sum+ld
        n=n//10
    return sum
n=int(input("enter val:"))
print(sum_individual(n))
# Out:
# 9

# %% [markdown]
# # 3.wap to print number between the range 2 to 10

# %%
def prime_num():
    for i in range(2,11):
        count=0
        for j in range(1,i+1):
            if i % j==0:
                count=count + 1
        if count==2:
            print(i,end=" ")
prime_num()
# Out:
# 2 3 5 7

# %% [markdown]
# # assignment question

# %% [markdown]
# # 4.wap to find product of individual digit

# %%
def product_individual(n):
    product = 1
    while n > 0:
        ld = n % 10
        product = product * ld
        n = n // 10
    return product

n = int(input("enter val: "))
print(product_individual(n))

# Input: 234
#
# 2 * 3 * 4 = 24
#
# Output: 24
# Out:
# 24

# %% [markdown]
# # 5.wap to count the number of digits present in a given number

# %%
def count_digits(n):
    count = 0
    while n > 0:
        n = n // 10
        count = count + 1
    return count

n = int(input("enter val: "))
print(count_digits(n))
# Input: 4567 → Output: 4
# Out:
# 6
